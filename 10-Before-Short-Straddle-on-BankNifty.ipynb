# %% [markdown]
# ### Run this trade at 9:18

# %%
from pya3 import *
import datetime as dt
import time

# %%
_id='Your id'
apikey = 'Your API key'

# %%
alice = Aliceblue(user_id=_id,api_key=apikey)

# %%
sessionid = alice.get_session_id() # Get Session ID

# %%
print(sessionid)
# Out:
# {'stat': 'Ok', 'sessionID': ''}

# %%
banknifty = alice.get_instrument_by_symbol('INDICES','NIFTY BANK')

# %%
###### Check trade Function
def check_trade():
    #alice=Aliceblue(_id,apikey)
    alice.get_session_id()['sessionID']
    signal = True
    days=1
    while(signal):
        try:
            exchange='INDICES'
            spot_symbol='NIFTY BANK'
            interval='D'
            indices=True
            from_date=dt.datetime.now()-dt.timedelta(days=days)
            to_date=dt.datetime.now()
            token=alice.get_instrument_by_symbol(exchange,spot_symbol)
            data=alice.get_historical(token,from_date,to_date,interval,indices)
            #print(data)
            y_high = data['high'][0]
            y_low = data['low'][0]
            today_open = data['open'][1]
            if(y_high > today_open and today_open > y_low):
                signal = False
                return True
            else:
                print("No Trade today")
                signal = False
                return False
        except:
            days = days + 1

# %%
Trade = check_trade()
print(Trade)
# Out:
# True

# %%
def get_curr_expiry(spot_ltp):
    spot_ltp = int(spot_ltp)
    print(f"Current expiry for {spot_ltp}")
    global datecale
    datecale = dt.date.today()
    while(1):
        expiry = alice.get_instrument_for_fno(exch="NFO",symbol='BANKNIFTY', expiry_date=str(datecale), is_fut=False,strike=spot_ltp, is_CE=True)
        #print(expiry)
        try:
            if list(expiry.values())[0] == 'Not_ok':
                print(f"{datecale} is not expiry")
                datecale = datecale + dt.timedelta(days=1)
            else:
                return datecale
                break
        except:
            return datecale

# %%
# get and Round off ltp on 09:20
# Entering into Trade
while(1):
    if (Trade == True):
        print(dt.datetime.now().time())
        if dt.datetime.now().time()>=dt.time(9,20,5):
            bnf_spot_ltp = float(alice.get_scrip_info(banknifty)['LTP'])
            round_bnf_spot_ltp = round((bnf_spot_ltp/100),0)*100
            bnf_expiry_date = get_curr_expiry(round_bnf_spot_ltp)
            ce_instrument = alice.get_instrument_for_fno(exch="NFO",symbol='BANKNIFTY', expiry_date=str(bnf_expiry_date),
                                                         is_fut=False,strike=round_bnf_spot_ltp, is_CE=True)
            pe_instrument = alice.get_instrument_for_fno(exch="NFO",symbol='BANKNIFTY', expiry_date=str(bnf_expiry_date),
                                                         is_fut=False,strike=round_bnf_spot_ltp, is_CE=False)
            cesell = float(alice.get_scrip_info(ce_instrument)['LTP'])#float(cedict['Prc'])
            pesell = float(alice.get_scrip_info(pe_instrument)['LTP'])#float(pedict['Prc'])
            if ((cesell + pesell > 272)):
                print(cesell + pesell)
                order1 = {  "instrument"        : ce_instrument,
                "order_type"        : OrderType.Market,
                "quantity"          : 25,
                "transaction_type"  : TransactionType.Sell,
                "product_type"      : ProductType.Intraday,
                "order_tag"         : "Order1"}
                order2 = {  "instrument"        : pe_instrument,
                "order_type"        : OrderType.Market,
                "quantity"          : 25,
                "transaction_type"  : TransactionType.Sell,
                "product_type"      : ProductType.Intraday,
                "order_tag"         : "Order2"}
                orders = [order1, order2]
                brorder = alice.place_basket_order(orders)
                print("Order placed")
                print(f"LTP is {bnf_spot_ltp} Sell PE and CE on {round_bnf_spot_ltp} Price at expiry {bnf_expiry_date}.")
                #print(ce_instrument,pe_instrument)
                break
            else:
                print("Not Trade today")
                break
        else:
            time.sleep(1)
    else:
        print("Not Trade today")
        break
# Out:
# 09:18:18.223667
# 09:18:19.234835
# 09:18:20.244050
# 09:18:21.257612
# 09:18:22.270005
# 09:18:23.279279
# 09:18:24.290545
# 09:18:25.301672
# 09:18:26.312828
# 09:18:27.325152
# 09:18:28.338550
# 09:18:29.349997
# 09:18:30.362032
# 09:18:31.376663
# 09:18:32.385692
# 09:18:33.391745
# 09:18:34.404210
# 09:18:35.412886
# 09:18:36.425726
# 09:18:37.437199
# 09:18:38.448592
# 09:18:39.459795
# 09:18:40.468575
# 09:18:41.482529
# 09:18:42.496761
# 09:18:43.510956
# 09:18:44.522167
# 09:18:45.536066
# 09:18:46.550752
# 09:18:47.563533
# 09:18:48.573633
# 09:18:49.586177
# 09:18:50.598256
# 09:18:51.613267
# 09:18:52.625683
# 09:18:53.640489
# 09:18:54.652610
# 09:18:55.660995
# 09:18:56.671823
# 09:18:57.682063
# 09:18:58.691480
# 09:18:59.696545
# 09:19:00.713539
# 09:19:01.725392
# 09:19:02.737218
# 09:19:03.749671
# 09:19:04.758411
# 09:19:05.769149
# 09:19:06.784348
# 09:19:07.794382
# 09:19:08.807531
# 09:19:09.821318
# 09:19:10.831651
# 09:19:11.838987
# 09:19:12.856207
# 09:19:13.866503
# 09:19:14.876437
# 09:19:15.886917
# 09:19:16.898585
# 09:19:17.905716
# 09:19:18.920284
# 09:19:19.932385
# 09:19:20.945067
# 09:19:21.960317
# 09:19:22.976286
# 09:19:23.990081
# 09:19:24.991227
# 09:19:26.004829
# 09:19:27.020687
# 09:19:28.035496
# 09:19:29.050002
# 09:19:30.064051
# 09:19:31.075107
# 09:19:32.086210
# 09:19:33.099020
# 09:19:34.109946
# 09:19:35.122840
# 09:19:36.132114
# 09:19:37.142438
# 09:19:38.160287
# 09:19:39.174565
# 09:19:40.187708
# 09:19:41.200486
# 09:19:42.220670
# 09:19:43.233036
# 09:19:44.240703
# 09:19:45.253398
# 09:19:46.256813
# 09:19:47.268018
# 09:19:48.281513
# 09:19:49.292716
# 09:19:50.301897
# 09:19:51.317026
# 09:19:52.325314
# 09:19:53.333276
# 09:19:54.343112
# 09:19:55.349049
# 09:19:56.361456
# 09:19:57.373920
# 09:19:58.381672
# 09:19:59.392842
# 09:20:00.400065
# 09:20:01.412401
# 09:20:02.423818
# 09:20:03.437338
# 09:20:04.451404
# 09:20:05.463401
# Current expiry for 44900
# 2023-07-14 is not expiry
# 2023-07-15 is not expiry
# 2023-07-16 is not expiry
# 2023-07-17 is not expiry
# 2023-07-18 is not expiry
# 2023-07-19 is not expiry
# 506.1
# Order placed
# LTP is 44885.95 Sell PE and CE on 44900.0 Price at expiry 2023-07-20.

# %%
## Calculating the Target and the StopLoss
cedict = alice.get_order_history(brorder[0]['NOrdNo'])
pedict = alice.get_order_history(brorder[1]['NOrdNo'])
cesell = float(alice.get_scrip_info(ce_instrument)['LTP'])#float(cedict['Prc'])
pesell = float(alice.get_scrip_info(pe_instrument)['LTP'])#float(pedict['Prc'])
points = round((((cesell + pesell) - (cesell + pesell) * 0.9)),2)
cesl = round((cesell + points),2)
pesl = round((pesell + points),2)
print("Points: ", points)
print("CE Sell Price: ", cesell)
print("PE Sell Price: ", pesell)
print("Value Sum: ",cesell + pesell)
# Out:
# Points:  50.58
# CE Sell Price:  251.15
# PE Sell Price:  254.7
# Value Sum:  505.85

# %%
## Calculating the trade 
End = False
while(1):
    time.sleep(5)
    celtp = float(alice.get_scrip_info(ce_instrument)['LTP'])
    peltp = float(alice.get_scrip_info(pe_instrument)['LTP'])
    if End == True:
        print("Trade Excuted")
        break
    elif (celtp >= cesl):
        print("Sell CE on Market price, 10 percent Loss at: ",celtp)
        while(1):
            if (peltp >= pesl):
                print("Sell PE on Market price, 10 percent Loss at: ",peltp)
                print(dt.datetime.now().time())
                End = True
                break
            elif (peltp <= (pesell - (points*2))):
                print("Sell PE on Market price, 20 percent Profit at: ",peltp)
                print(dt.datetime.now().time())
                End = True
                break
            else:
                print(f"PE sell price: {peltp}")
                #celtp = float(alice.get_scrip_info(ce_instrument)['LTP'])
                peltp = float(alice.get_scrip_info(pe_instrument)['LTP'])
                time.sleep(5)
    elif (peltp >= pesl):
        print("Sell PE on Market price, 10 percent Loss at: ",peltp)
        while(1):
            
            if (celtp >= cesl):
                print("Sell CE on Market price, 10 percent Loss at: ",celtp)
                print(dt.datetime.now().time())
                End = True
                break
            elif (celtp <= (cesell - (points*2))):
                print("Sell CE on Market price, 20 percent Profit at: ",celtp)
                print(dt.datetime.now().time())
                End = True
                break
            else:
                print(f"CE sell price: {celtp}")
                celtp = float(alice.get_scrip_info(ce_instrument)['LTP'])
                #peltp = float(alice.get_scrip_info(pe_instrument)['LTP'])
                time.sleep(5)
    else:
        try :
            print(f"Current Sum: {celtp + peltp} and Running Profit/Loss: {(cesell + pesell)-(celtp + peltp)}")
        except:
            print("Not get LTP")
            time.sleep(10)
# Out:
# Sell PE on Market price, 10 percent Loss at:  350.75
# CE sell price: 173.9
# CE sell price: 174.15
# CE sell price: 174.8
# CE sell price: 175.2
# CE sell price: 174.9
# CE sell price: 175.8
# CE sell price: 176.25
# CE sell price: 176.55
# CE sell price: 177.35
# CE sell price: 175.55
# CE sell price: 177.0
# CE sell price: 177.5
# CE sell price: 179.95
# CE sell price: 177.95
# CE sell price: 179.35
# CE sell price: 180.15
# CE sell price: 180.55
# CE sell price: 177.4
# CE sell price: 177.8
# CE sell price: 177.9
# CE sell price: 177.45
# CE sell price: 176.55
# CE sell price: 176.25
# CE sell price: 176.3
# CE sell price: 175.4
# CE sell price: 177.75
# CE sell price: 177.4
# CE sell price: 178.0
# CE sell price: 177.6
# CE sell price: 178.75
# CE sell price: 178.25
# CE sell price: 178.8
# CE sell price: 178.6
# CE sell price: 179.8
# CE sell price: 179.4
# CE sell price: 178.15
# CE sell price: 178.0
# CE sell price: 177.65
# CE sell price: 177.25
# CE sell price: 177.7
# CE sell price: 176.95
# CE sell price: 175.85
# CE sell price: 176.0
# CE sell price: 175.95
# CE sell price: 176.0
# CE sell price: 175.65
# CE sell price: 175.65
# CE sell price: 176.6
# CE sell price: 176.75
# CE sell price: 176.7
# CE sell price: 175.8
# CE sell price: 175.65
# CE sell price: 175.5
# CE sell price: 175.4
# CE sell price: 176.9
# CE sell price: 178.6
# CE sell price: 178.1
# CE sell price: 176.75
# CE sell price: 178.0
# CE sell price: 178.25
# CE sell price: 178.05
# CE sell price: 180.6
# CE sell price: 180.25
# CE sell price: 180.95
# CE sell price: 181.25
# CE sell price: 181.45
# CE sell price: 179.5
# CE sell price: 179.65
# CE sell price: 180.0
# CE sell price: 181.35
# CE sell price: 181.85
# CE sell price: 181.8
# CE sell price: 180.1
# CE sell price: 179.9
# CE sell price: 179.25
# CE sell price: 181.65
# CE sell price: 182.5
# CE sell price: 184.05
# CE sell price: 183.7
# CE sell price: 184.5
# CE sell price: 184.3
# CE sell price: 184.0
# CE sell price: 183.5
# CE sell price: 183.4
# CE sell price: 182.7
# CE sell price: 182.35
# CE sell price: 184.05
# CE sell price: 186.15
# CE sell price: 186.75
# CE sell price: 185.7
# CE sell price: 187.85
# CE sell price: 188.6
# CE sell price: 188.9
# CE sell price: 187.5
# CE sell price: 187.0
# CE sell price: 186.65
# CE sell price: 187.7
# CE sell price: 186.8
# CE sell price: 188.1
# CE sell price: 189.8
# CE sell price: 189.15
# CE sell price: 189.05
# CE sell price: 188.0
# CE sell price: 189.0
# CE sell price: 186.1
# CE sell price: 188.7
# CE sell price: 189.1
# CE sell price: 188.45
# CE sell price: 189.5
# CE sell price: 189.95
# CE sell price: 187.25
# CE sell price: 188.3
# CE sell price: 189.2
# CE sell price: 188.05
# CE sell price: 187.8
# CE sell price: 186.8
# CE sell price: 187.65
# CE sell price: 187.4
# CE sell price: 186.15
# CE sell price: 188.45
# CE sell price: 189.1
# CE sell price: 188.2
# CE sell price: 191.15
# CE sell price: 190.9
# CE sell price: 191.2
# CE sell price: 190.4
# CE sell price: 189.6
# CE sell price: 192.1
# CE sell price: 190.95
# CE sell price: 190.9
# CE sell price: 190.6
# CE sell price: 190.25
# CE sell price: 191.15
# CE sell price: 192.1
# CE sell price: 191.05
# CE sell price: 190.75
# CE sell price: 189.6
# CE sell price: 190.3
# CE sell price: 191.0
# CE sell price: 192.05
# CE sell price: 192.0
# CE sell price: 191.3
# CE sell price: 190.55
# CE sell price: 191.45
# CE sell price: 190.2
# CE sell price: 190.25
# CE sell price: 189.5
# CE sell price: 187.35
# CE sell price: 185.75
# CE sell price: 186.0
# CE sell price: 186.6
# CE sell price: 186.4
# CE sell price: 186.2
# CE sell price: 185.25
# CE sell price: 183.9
# CE sell price: 184.25
# CE sell price: 184.45
# CE sell price: 182.8
# CE sell price: 181.4
# CE sell price: 181.0
# CE sell price: 179.7
# CE sell price: 179.75
# CE sell price: 181.0
# CE sell price: 182.9
# CE sell price: 184.0
# CE sell price: 185.9
# CE sell price: 183.95
# CE sell price: 185.3
# CE sell price: 184.0
# CE sell price: 183.1
# CE sell price: 182.6
# CE sell price: 182.6
# CE sell price: 184.15
# CE sell price: 184.85
# CE sell price: 185.85
# CE sell price: 186.0
# CE sell price: 185.05
# CE sell price: 184.0
# CE sell price: 183.55
# CE sell price: 182.3
# CE sell price: 182.35
# CE sell price: 181.05
# CE sell price: 182.55
# CE sell price: 182.35
# CE sell price: 184.85
# CE sell price: 185.15
# CE sell price: 185.75
# CE sell price: 186.15
# CE sell price: 186.45
# CE sell price: 186.0
# CE sell price: 186.25
# CE sell price: 185.35
# CE sell price: 184.35
# CE sell price: 185.05
# CE sell price: 183.95
# CE sell price: 184.6
# CE sell price: 183.65
# CE sell price: 183.0
# CE sell price: 182.75
# CE sell price: 182.75
# CE sell price: 184.25
# CE sell price: 184.5
# CE sell price: 185.2
# CE sell price: 185.4
# CE sell price: 186.3
# CE sell price: 185.8
# CE sell price: 185.95
# CE sell price: 185.6
# CE sell price: 185.55
# CE sell price: 185.55
# CE sell price: 186.1
# CE sell price: 186.75
# CE sell price: 185.3
# CE sell price: 186.4
# CE sell price: 186.45
# CE sell price: 185.95
# CE sell price: 186.7
# CE sell price: 186.1
# CE sell price: 185.75
# CE sell price: 187.8
# CE sell price: 186.85
# CE sell price: 186.7
# CE sell price: 187.0
# CE sell price: 187.6
# CE sell price: 188.15
# CE sell price: 189.05
# CE sell price: 188.65
# CE sell price: 188.6
# CE sell price: 189.0
# CE sell price: 188.85
# CE sell price: 188.25
# CE sell price: 188.7
# CE sell price: 188.3
# CE sell price: 188.35
# CE sell price: 189.1
# CE sell price: 188.7
# CE sell price: 189.1
# CE sell price: 188.8
# CE sell price: 189.5
# CE sell price: 190.4
# CE sell price: 189.0
# CE sell price: 191.15
# CE sell price: 191.95
# CE sell price: 192.15
# CE sell price: 191.6
# CE sell price: 191.35
# CE sell price: 192.45
# CE sell price: 193.35
# CE sell price: 192.75
# CE sell price: 194.0
# CE sell price: 193.4
# CE sell price: 193.65
# CE sell price: 193.95
# CE sell price: 192.15
# CE sell price: 191.65
# CE sell price: 191.15
# CE sell price: 190.65
# CE sell price: 192.55
# CE sell price: 190.9
# CE sell price: 191.9
# CE sell price: 190.45
# CE sell price: 187.75
# CE sell price: 185.9
# CE sell price: 185.85
# CE sell price: 184.1
# CE sell price: 186.8
# CE sell price: 187.15
# CE sell price: 187.15
# CE sell price: 187.8
# CE sell price: 186.25
# CE sell price: 184.55
# CE sell price: 182.75
# CE sell price: 181.25
# CE sell price: 181.65
# CE sell price: 184.3
# CE sell price: 183.95
# CE sell price: 186.8
# CE sell price: 185.85
# CE sell price: 184.05
# CE sell price: 183.75
# CE sell price: 184.5
# CE sell price: 183.65
# CE sell price: 182.8
# CE sell price: 183.6
# CE sell price: 180.9
# CE sell price: 181.45
# CE sell price: 180.55
# CE sell price: 180.8
# CE sell price: 180.7
# CE sell price: 182.35
# CE sell price: 183.15
# CE sell price: 182.8
# CE sell price: 183.3
# CE sell price: 181.6
# CE sell price: 183.7
# CE sell price: 183.3
# CE sell price: 182.55
# CE sell price: 182.1
# CE sell price: 181.1
# CE sell price: 179.0
# CE sell price: 179.15
# CE sell price: 178.3
# CE sell price: 177.0
# CE sell price: 176.85
# CE sell price: 176.3
# CE sell price: 175.85
# CE sell price: 176.25
# CE sell price: 176.05
# CE sell price: 174.6
# CE sell price: 175.35
# CE sell price: 174.3
# CE sell price: 176.45
# CE sell price: 175.35
# CE sell price: 176.65
# CE sell price: 177.9
# CE sell price: 176.7
# CE sell price: 176.25
# CE sell price: 176.0
# CE sell price: 174.05
# CE sell price: 174.0
# CE sell price: 173.0
# CE sell price: 171.75
# CE sell price: 171.3
# CE sell price: 172.0
# CE sell price: 171.95
# CE sell price: 168.55
# CE sell price: 168.25
# CE sell price: 169.0
# CE sell price: 170.8
# CE sell price: 168.65
# CE sell price: 167.55
# CE sell price: 169.2
# CE sell price: 170.75
# CE sell price: 172.55
# CE sell price: 169.25
# CE sell price: 167.75
# CE sell price: 169.35
# CE sell price: 169.95
# CE sell price: 172.35
# CE sell price: 171.65
# CE sell price: 171.3
# CE sell price: 170.15
# CE sell price: 169.8
# CE sell price: 170.6
# CE sell price: 168.2
# CE sell price: 168.9
# CE sell price: 168.5
# CE sell price: 170.4
# CE sell price: 170.65
# CE sell price: 172.0
# CE sell price: 172.35
# CE sell price: 171.75
# CE sell price: 172.5
# CE sell price: 172.25
# CE sell price: 170.7
# CE sell price: 170.0
# CE sell price: 169.5
# CE sell price: 169.55
# CE sell price: 169.85
# CE sell price: 168.75
# CE sell price: 169.35
# CE sell price: 170.05
# CE sell price: 172.35
# CE sell price: 170.15
# CE sell price: 170.05
# CE sell price: 171.35
# CE sell price: 170.55
# CE sell price: 170.45
# CE sell price: 170.7
# CE sell price: 170.2
# CE sell price: 170.0
# CE sell price: 170.0
# CE sell price: 170.35
# CE sell price: 172.65
# CE sell price: 173.5
# CE sell price: 172.3
# CE sell price: 170.5
# CE sell price: 170.65
# CE sell price: 170.95
# CE sell price: 170.55
# CE sell price: 171.3
# CE sell price: 173.1
# CE sell price: 172.1
# CE sell price: 171.85
# CE sell price: 173.3
# CE sell price: 173.0
# CE sell price: 172.15
# CE sell price: 172.45
# CE sell price: 172.75
# CE sell price: 173.0
# CE sell price: 172.2
# CE sell price: 172.1
# CE sell price: 174.2
# CE sell price: 174.9
# CE sell price: 176.2
# CE sell price: 176.8
# CE sell price: 177.4
# CE sell price: 177.35
# CE sell price: 173.85
# CE sell price: 176.3
# CE sell price: 176.65
# CE sell price: 177.8
# CE sell price: 177.8
# CE sell price: 177.45
# CE sell price: 178.7
# CE sell price: 179.55
# CE sell price: 179.65
# CE sell price: 179.1
# CE sell price: 180.65
# CE sell price: 178.55
# CE sell price: 180.25
# CE sell price: 178.05
# CE sell price: 178.35
# CE sell price: 179.75
# CE sell price: 181.0
# CE sell price: 179.2
# CE sell price: 179.35
# CE sell price: 179.75
# CE sell price: 180.4
# CE sell price: 179.8
# CE sell price: 178.6
# CE sell price: 178.55
# CE sell price: 176.35
# CE sell price: 175.2
# CE sell price: 175.15
# CE sell price: 176.45
# CE sell price: 174.55
# CE sell price: 174.0
# CE sell price: 175.2
# CE sell price: 175.95
# CE sell price: 175.5
# CE sell price: 175.5
# CE sell price: 176.3
# CE sell price: 176.1
# CE sell price: 176.55
# CE sell price: 176.35
# CE sell price: 177.35
# CE sell price: 177.1
# CE sell price: 176.7
# CE sell price: 177.0
# CE sell price: 176.95
# CE sell price: 177.1
# CE sell price: 176.9
# CE sell price: 176.25
# CE sell price: 175.65
# CE sell price: 173.5
# CE sell price: 172.95
# CE sell price: 171.65
# CE sell price: 172.45
# CE sell price: 172.4
# CE sell price: 173.9
# CE sell price: 173.0
# CE sell price: 172.4
# CE sell price: 173.4
# CE sell price: 173.15
# CE sell price: 171.25
# CE sell price: 171.0
# CE sell price: 170.55
# CE sell price: 168.6
# CE sell price: 169.3
# CE sell price: 170.35
# CE sell price: 168.55
# CE sell price: 168.2
# CE sell price: 168.7
# CE sell price: 169.6
# CE sell price: 170.5
# CE sell price: 169.85
# CE sell price: 168.6
# CE sell price: 156.6
# CE sell price: 155.7
# CE sell price: 155.0
# Sell CE on Market price, 20 percent Profit at:  149.5
# 13:47:36.194504
# Trade Excuted

# %%
(cesell - (points*2))
# Out:
# 149.99
